# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Lenovo/Desktop/House_Rent_Analysis/Dataset/June_8_data_metro_closest_stations.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  size_sq_ft       propertyType  bedrooms   latitude  longitude  \
# 0           0         400  Independent Floor         1  28.641010  77.284386
# 1           1        1050          Apartment         2  28.594969  77.298668
# 2           2        2250  Independent Floor         2  28.641806  77.293922
# 3           3        1350  Independent Floor         2  28.644363  77.293228
# 4           4         450          Apartment         2  28.594736  77.311150
#
#    suburbName cityName  price             companyName  \
# 0  East Delhi    Delhi   9000             Dream Homez
# 1  East Delhi    Delhi  20000  Rupak Properties Stock
# 2  East Delhi    Delhi  28000   Aashiyana Real Estate
# 3  East Delhi    Delhi  28000      Shivam Real Estate
# 4  East Delhi    Delhi  12500        Shree Properties
#
#    closest_mtero_station_km  AP_dist_km  Aiims_dist_km  NDRLW_dist_km
# 0                  0.577495   21.741188      11.119239       6.227231
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'size_sq_ft', 'propertyType', 'bedrooms', 'latitude',
#        'longitude', 'suburbName', 'cityName', 'price', 'companyName',
#        'closest_mtero_station_km', 'AP_dist_km', 'Aiims_dist_km',
#        'NDRLW_dist_km'],
#       dtype='object')

# %%
df.rename(columns = {'Unnamed: 0':'IndexNo'}, inplace = True)

# %%
df.head()
# Out:
#    IndexNo  size_sq_ft       propertyType  bedrooms   latitude  longitude  \
# 0        0         400  Independent Floor         1  28.641010  77.284386
# 1        1        1050          Apartment         2  28.594969  77.298668
# 2        2        2250  Independent Floor         2  28.641806  77.293922
# 3        3        1350  Independent Floor         2  28.644363  77.293228
# 4        4         450          Apartment         2  28.594736  77.311150
#
#    suburbName cityName  price             companyName  \
# 0  East Delhi    Delhi   9000             Dream Homez
# 1  East Delhi    Delhi  20000  Rupak Properties Stock
# 2  East Delhi    Delhi  28000   Aashiyana Real Estate
# 3  East Delhi    Delhi  28000      Shivam Real Estate
# 4  East Delhi    Delhi  12500        Shree Properties
#
#    closest_mtero_station_km  AP_dist_km  Aiims_dist_km  NDRLW_dist_km
# 0                  0.577495   21.741188      11.119239       6.227231
# ...

# %%
df.describe()
# Out:
#             IndexNo    size_sq_ft      bedrooms      latitude     longitude  \
# count  17890.000000  17890.000000  17890.000000  17890.000000  17890.000000
# mean    8944.500000   1176.342091      2.168865     28.609382     77.168368
# std     5164.542493    873.751044      0.971414      0.099547      0.097611
# min        0.000000    100.000000      1.000000     19.185120     73.213829
# 25%     4472.250000    620.000000      1.000000     28.562540     77.103718
# 50%     8944.500000    900.000000      2.000000     28.611803     77.168755
# 75%    13416.750000   1600.000000      3.000000     28.651593     77.224998
# max    17889.000000  16521.000000     15.000000     28.872597     80.358467
#
#               price  closest_mtero_station_km    AP_dist_km  Aiims_dist_km  \
# count  1.789000e+04              17890.000000  17890.000000   17890.000000
# mean   3.345196e+04                  0.931495     13.727784      11.238134
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17890 entries, 0 to 17889
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   IndexNo                   17890 non-null  int64
#  1   size_sq_ft                17890 non-null  int64
#  2   propertyType              17890 non-null  object
#  3   bedrooms                  17890 non-null  int64
#  4   latitude                  17890 non-null  float64
#  5   longitude                 17890 non-null  float64
#  6   suburbName                17890 non-null  object
#  7   cityName                  17890 non-null  object
#  8   price                     17890 non-null  int64
#  9   companyName               17890 non-null  object
#  10  closest_mtero_station_km  17890 non-null  float64
#  11  AP_dist_km                17890 non-null  float64
#  12  Aiims_dist_km             17890 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# IndexNo                     0
# size_sq_ft                  0
# propertyType                0
# bedrooms                    0
# latitude                    0
# longitude                   0
# suburbName                  0
# cityName                    0
# price                       0
# companyName                 0
# closest_mtero_station_km    0
# AP_dist_km                  0
# Aiims_dist_km               0
# NDRLW_dist_km               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# IndexNo                     0
# size_sq_ft                  0
# propertyType                0
# bedrooms                    0
# latitude                    0
# longitude                   0
# suburbName                  0
# cityName                    0
# price                       0
# companyName                 0
# closest_mtero_station_km    0
# AP_dist_km                  0
# Aiims_dist_km               0
# NDRLW_dist_km               0
# dtype: int64

# %%
df['companyName'].value_counts()
# Out:
# Gurmeet                668
# Sky Properties         384
# Jagdamba Associates    307
# dwarka property        243
# Arora Associates       243
#                       ...
# BHAGAT SINGH NEGI        1
# Simmy Gupta              1
# Divya                    1
# shalini                  1
# ANIL KUMAR BAREJA        1
# Name: companyName, Length: 1387, dtype: int64

# %%
df['companyName'].unique()
# Out:
# array(['Dream Homez', 'Rupak Properties Stock', 'Aashiyana Real Estate',
#        ..., 'K K LAVANIA', 'sanjeev', 'ANIL KUMAR BAREJA'], dtype=object)

# %%
df['companyName'].nunique()
# Out:
# 1387

# %%
df['companyName']=df.companyName.str.replace('A to Z Property','A_to_Z_Property').str.replace('A 2 Z Property','A_to_Z_Property').str.replace('A to z realty','A_to_Z_Property')

# %%
df['companyName'].value_counts()
# Out:
# Gurmeet                668
# Sky Properties         384
# Jagdamba Associates    307
# dwarka property        243
# Arora Associates       243
#                       ...
# Raj Kumar                1
# kunal                    1
# Savita chhabra           1
# RAJAN                    1
# ANIL KUMAR BAREJA        1
# Name: companyName, Length: 1385, dtype: int64

# %%
company_names=df['companyName'].values.tolist()

# %%
type(company_names)
# Out:
# list

# %%
len(company_names)
# Out:
# 17890

# %%
unique_company_names=[]
for name in company_names:
    if name not in unique_company_names:
        unique_company_names.append(name)

# %%
len(unique_company_names)
# Out:
# 1385

# %%
for i in range(0,len(company_names)-1):
    if company_names.count(company_names[i]) < 50:
        company_names[i]='Others'

# %%
company_names
# Out:
# ['Others',
#  'Others',
#  'Others',
#  'Shivam Real Estate',
#  'Others',
#  'Golden Properties',
#  'Welcome Properties',
#  'Akash Properties',
#  'Shivam Properties',
#  'Others',
#  'Tanya Associates',
#  'BK Associates',
#  'Hans Properties',
#  'Aaditya properties',
#  'Prince Associates',
#  'Others',
#  'Arora Properties',
#  'Aradhya Properties',
#  'Others',
#  'Others',
#  'Others',
#  'Delli Property',
#  'Others',
#  'Golden Properties',
#  'Shivam Real Estate',
#  'Welcome Properties',
#  'Others',
#  'Shivam Properties',
#  'Akash Properties',
#  'BK Associates',
#  'Others',
#  'Others',
#  'Others',
#  'Prince Associates',
#  'Arora Properties',
#  'Others',
#  'Shivam Real Estate',
#  'Others',
#  'Others',
#  'Shivam Properties',
#  'Golden Properties',
#  'BK Associates',
#  'Prince Associates',
#  'Welcome Properties',
#  'Akash Properties',
#  'Arora Properties',
#  'Others',
#  'Others',
#  'Others',
#  'Shivam Real Estate',
#  'Others',
# ...

# %%
new_company_names= pd.DataFrame(company_names)

# %%
type(new_company_names)
# Out:
# pandas.core.frame.DataFrame

# %%
df['companyName']=new_company_names

# %%
df['companyName']
# Out:
# 0                    Others
# 1                    Others
# 2                    Others
# 3        Shivam Real Estate
# 4                    Others
#                 ...
# 17885                Others
# 17886                Others
# 17887                Others
# 17888                Others
# 17889               sanjeev
# Name: companyName, Length: 17890, dtype: object

# %%
df['companyName'].value_counts()
# Out:
# Others                           6517
# Gurmeet                           668
# Sky Properties                    384
# Jagdamba Associates               307
# dwarka property                   243
#                                  ...
# Welcome Properties                 52
# Mass Properties                    51
# Ambika Properties                  51
# Shubham Estates / Shubhbhoomi      50
# sanjeev                             1
# Name: companyName, Length: 114, dtype: int64

# %%
df['companyName'].unique()
# Out:
# array(['Others', 'Shivam Real Estate', 'Golden Properties',
#        'Welcome Properties', 'Akash Properties', 'Shivam Properties',
#        'Tanya Associates', 'BK Associates', 'Hans Properties',
#        'Aaditya properties', 'Prince Associates', 'Arora Properties',
#        'Aradhya Properties', 'Delli Property', 'Rana Associates',
#        'ASAssociates', 'Nestaway', 'Mass Properties', 'sk roy',
#        'vajpayee properties', 'golden properties', 'DKS Realty Homes',
#        'A_to_Z_Property', 'user', 'SkyLark Properties',
#        'Shiv Shakti Properties Consultant Builders', 'VR Property',
#        'B M Associates', 'Sethi Properties', 'Jagdamba Associates',
#        'dwarka property', 'Bm properties', 'Shivansh Associate',
#        'Batra Associates', 'Atul Kumar', 'Guru kipra properties',
#        'Baghla Estates', 'Deepak Verma', 'Property Hub', 'Realty Centre',
#        'New golden properties', 'K Homes', 'NCR Investors',
# ...

# %%
df.to_csv("new_house_data.csv",index=False)

# %%
new_df=pd.read_csv("new_house_data.csv")

# %%
new_df.head()
# Out:
#    IndexNo  size_sq_ft       propertyType  bedrooms   latitude  longitude  \
# 0        0         400  Independent Floor         1  28.641010  77.284386
# 1        1        1050          Apartment         2  28.594969  77.298668
# 2        2        2250  Independent Floor         2  28.641806  77.293922
# 3        3        1350  Independent Floor         2  28.644363  77.293228
# 4        4         450          Apartment         2  28.594736  77.311150
#
#    suburbName cityName  price         companyName  closest_mtero_station_km  \
# 0  East Delhi    Delhi   9000              Others                  0.577495
# 1  East Delhi    Delhi  20000              Others                  0.417142
# 2  East Delhi    Delhi  28000              Others                  0.125136
# 3  East Delhi    Delhi  28000  Shivam Real Estate                  0.371709
# 4  East Delhi    Delhi  12500              Others                  1.087760
#
#    AP_dist_km  Aiims_dist_km  NDRLW_dist_km
# ...
