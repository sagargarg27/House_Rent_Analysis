# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://127.0.0.1:27017/')

# %%
mydb = client['Project']

# %%
information = mydb.HouseRent

# %%
information.find_one()
# Out:
# {'_id': ObjectId('64031fc5e52becc469813225'),
#  'size_sq_ft': 400,
#  'propertyType': 'Independent Floor',
#  'bedrooms': 1,
#  'latitude': 28.64101028,
#  'longitude': 77.28438568,
#  'localityName': 'Swasthya Vihar',
#  'suburbName': 'East Delhi',
#  'companyName': 'Dream Homez',
#  'closest_metro_station_km': 0.577495488,
#  'AP_dist_km': 21.74118752,
#  'Aiims_dist_km': 11.11923914,
#  'NDRLW_dist_km': 6.227231356,
#  'price': 9000}

# %%
for i in information.find({'propertyType':'Villa'}):
    print(i)
# Out:
# {'_id': ObjectId('64031fc5e52becc46981329d'), 'size_sq_ft': 1900, 'propertyType': 'Villa', 'bedrooms': 4, 'latitude': 28.63539124, 'longitude': 77.28744507, 'localityName': 'Preet Vihar', 'suburbName': 'East Delhi', 'companyName': 'Aashiyana Real Estate', 'closest_metro_station_km': 0.295026741, 'AP_dist_km': 21.74814789, 'Aiims_dist_km': 10.87956911, 'NDRLW_dist_km': 6.563411823, 'price': 40000}
# {'_id': ObjectId('64031fc5e52becc4698135c8'), 'size_sq_ft': 11000, 'propertyType': 'Villa', 'bedrooms': 5, 'latitude': 28.51698494, 'longitude': 77.0941391, 'localityName': 'Kapashera', 'suburbName': 'East Delhi', 'companyName': 'Mukesh', 'closest_metro_station_km': 3.945664725, 'AP_dist_km': 4.302654864, 'Aiims_dist_km': 12.42169014, 'NDRLW_dist_km': 18.55670132, 'price': 415000}
# ...

# %%
import pymongoarrow, pymongoarrow.api

# %%
df = pymongoarrow.api.find_pandas_all(information, {})

# %%
df
# Out:
#                                            _id  size_sq_ft       propertyType  \
# 0         b'd\x03\x1f\xc5\xe5+\xec\xc4i\x812%'         400  Independent Floor
# 1         b'd\x03\x1f\xc5\xe5+\xec\xc4i\x812&'        1050          Apartment
# 2         b"d\x03\x1f\xc5\xe5+\xec\xc4i\x812'"        2250  Independent Floor
# 3         b'd\x03\x1f\xc5\xe5+\xec\xc4i\x812('        1350  Independent Floor
# 4         b'd\x03\x1f\xc5\xe5+\xec\xc4i\x812)'         450          Apartment
# ...                                        ...         ...                ...
# 17885  b'd\x03\x1f\xc6\xe5+\xec\xc4i\x81x\x02'         270  Independent Floor
# 17886  b'd\x03\x1f\xc6\xe5+\xec\xc4i\x81x\x03'        1000  Independent Floor
# 17887  b'd\x03\x1f\xc6\xe5+\xec\xc4i\x81x\x04'        1400  Independent Floor
# 17888  b'd\x03\x1f\xc6\xe5+\xec\xc4i\x81x\x05'         900  Independent Floor
# 17889  b'd\x03\x1f\xc6\xe5+\xec\xc4i\x81x\x06'        1000  Independent Floor
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
