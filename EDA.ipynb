# %% [markdown]
# # Exploratory Data Analysis(EDA)
# Let's begin some exploratory data analysis!.

# %% [markdown]
# # Import Libraries
# Let's import some libraries to get started

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading dataset
# Let's start by reading house rent dataset into a pandas dataframe

# %%
house_rent=pd.read_csv("Dataset/ProcessedFile.csv")

# %%
house_rent.head()
# Out:
#    size_sq_ft       propertyType  bedrooms   latitude  longitude  \
# 0         400  Independent Floor         1  28.641010  77.284386
# 1        1050          Apartment         2  28.594969  77.298668
# 2        2250  Independent Floor         2  28.641806  77.293922
# 3        1350  Independent Floor         2  28.644363  77.293228
# 4         450          Apartment         2  28.594736  77.311150
#
#           localityName  suburbName companyName  closest_metro_station_km  \
# 0       Swasthya Vihar  East Delhi       Other                  0.577495
# 1  mayur vihar phase 1  East Delhi       Other                  0.417142
# 2       Swasthya Vihar  East Delhi       Other                  0.125136
# 3        Krishna Nagar  East Delhi       Other                  0.371709
# 4      New Ashok Nagar  East Delhi       Other                  1.087760
#
#    AP_dist_km  Aiims_dist_km  NDRLW_dist_km  price
# 0   21.741188      11.119239       6.227231   9000
# ...

# %%
house_rent.columns
# Out:
# Index(['size_sq_ft', 'propertyType', 'bedrooms', 'latitude', 'longitude',
#        'localityName', 'suburbName', 'companyName', 'closest_metro_station_km',
#        'AP_dist_km', 'Aiims_dist_km', 'NDRLW_dist_km', 'price'],
#       dtype='object')

# %%
house_rent.dtypes
# Out:
# size_sq_ft                    int64
# propertyType                 object
# bedrooms                      int64
# latitude                    float64
# longitude                   float64
# localityName                 object
# suburbName                   object
# companyName                  object
# closest_metro_station_km    float64
# AP_dist_km                  float64
# Aiims_dist_km               float64
# NDRLW_dist_km               float64
# price                         int64
# dtype: object

# %%
house_rent.describe()
# Out:
#          size_sq_ft      bedrooms      latitude     longitude  \
# count  17890.000000  17890.000000  17890.000000  17890.000000
# mean    1176.342091      2.168865     28.609382     77.168368
# std      873.751044      0.971414      0.099547      0.097611
# min      100.000000      1.000000     19.185120     73.213829
# 25%      620.000000      1.000000     28.562540     77.103718
# 50%      900.000000      2.000000     28.611803     77.168755
# 75%     1600.000000      3.000000     28.651593     77.224998
# max    16521.000000     15.000000     28.872597     80.358467
#
#        closest_metro_station_km    AP_dist_km  Aiims_dist_km  NDRLW_dist_km  \
# count              17890.000000  17890.000000   17890.000000   17890.000000
# mean                   0.931495     13.727784      11.238134      11.421994
# std                    8.287856     11.357063      11.167202      11.063323
# min                    0.000692      1.784779       0.634508       0.722023
# ...

# %%
house_rent.nunique()
# Out:
# size_sq_ft                   700
# propertyType                   4
# bedrooms                      12
# latitude                    8767
# longitude                   7651
# localityName                 781
# suburbName                     8
# companyName                  102
# closest_metro_station_km    9765
# AP_dist_km                  9765
# Aiims_dist_km               9765
# NDRLW_dist_km               9765
# price                        432
# dtype: int64

# %%
house_rent.shape
# Out:
# (17890, 13)

# %%
house_rent['suburbName'].unique()
# Out:
# array(['East Delhi', 'North West Delhi', 'South Delhi', 'West Delhi',
#        'North Delhi', 'South West Delhi', 'Central Delhi', 'Other'],
#       dtype=object)

# %%
house_rent['propertyType'].unique()
# Out:
# array(['Independent Floor', 'Apartment', 'Independent House', 'Villa'],
#       dtype=object)

# %%
house_rent['bedrooms'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, 10, 15, 12,  8,  9], dtype=int64)

# %%
house_rent['companyName'].unique()
# Out:
# array(['Other', 'Mukesh', 'Jain Builder properties', 'Kunal Associates',
#        'AMPM Realtors', 'Swastik Properties', 'pransu Srivastava',
#        'Jain builders and properties', 'S K JAIN', 'Abhishek yadav',
#        'Atul Kumar', 'Baghla Estates',
#        'Find A House Real Estate Consultants', 'Property Hub',
#        'Realty Centre', 'Brickhouse Realty Solutions', 'NCR Investors',
#        'Delhi dreams properties consultant',
#        'Panworld Property Consultants', 'Ritu Estates',
#        'Property Linkers', 'Smart Homes', 'India Homes',
#        'Moneytree real estate consultants', 'HR Associates',
#        'Property Gallery', 'A R Realtors', 'Navigators Estate',
#        'Shakuntala Buildcon', 'Dinesh associates', 'Hari Om Group',
#        'Angel Property Services', 'Rohit', 'ONS Realtors',
#        'Laxmipati Associates PvtLtd', 'India Z Homes',
#        'Destination Realty Solutions Private Limited', 'Neon Properties',
# ...

# %% [markdown]
# ##  Missing Data
# We can use seaborn to create a simple heatmap to see where we are missing data!

# %%
house_rent.isnull()
# Out:
#        size_sq_ft  propertyType  bedrooms  latitude  longitude  localityName  \
# 0           False         False     False     False      False         False
# 1           False         False     False     False      False         False
# 2           False         False     False     False      False         False
# 3           False         False     False     False      False         False
# 4           False         False     False     False      False         False
# ...           ...           ...       ...       ...        ...           ...
# 17885       False         False     False     False      False         False
# 17886       False         False     False     False      False         False
# 17887       False         False     False     False      False         False
# 17888       False         False     False     False      False         False
# 17889       False         False     False     False      False         False
#
# ...

# %%
house_rent.isnull().sum()
# Out:
# size_sq_ft                  0
# propertyType                0
# bedrooms                    0
# latitude                    0
# longitude                   0
# localityName                0
# suburbName                  0
# companyName                 0
# closest_metro_station_km    0
# AP_dist_km                  0
# Aiims_dist_km               0
# NDRLW_dist_km               0
# price                       0
# dtype: int64

# %%
#Using Seaborn library to see missing values
sns.heatmap(house_rent.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# By seeing above graph we can see that there is no missing values in house rent dataset

# %%
# Dropping the redundant data which is less important for analysis and prediction
rent_data=house_rent.drop(['latitude','longitude'],axis=1)

# %%
rent_data.head()
# Out:
#    size_sq_ft       propertyType  bedrooms         localityName  suburbName  \
# 0         400  Independent Floor         1       Swasthya Vihar  East Delhi
# 1        1050          Apartment         2  mayur vihar phase 1  East Delhi
# 2        2250  Independent Floor         2       Swasthya Vihar  East Delhi
# 3        1350  Independent Floor         2        Krishna Nagar  East Delhi
# 4         450          Apartment         2      New Ashok Nagar  East Delhi
#
#   companyName  closest_metro_station_km  AP_dist_km  Aiims_dist_km  \
# 0       Other                  0.577495   21.741188      11.119239
# 1       Other                  0.417142   21.401856       9.419061
# 2       Other                  0.125136   22.620365      11.829486
# 3       Other                  0.371709   22.681201      11.982708
# 4       Other                  1.087760   22.592810      10.571573
#
#    NDRLW_dist_km  price
# 0       6.227231   9000
# 1       9.217502  20000
# 2       7.159184  28000
# ...

# %%
rent_data.describe()
# Out:
#          size_sq_ft      bedrooms  closest_metro_station_km    AP_dist_km  \
# count  17890.000000  17890.000000              17890.000000  17890.000000
# mean    1176.342091      2.168865                  0.931495     13.727784
# std      873.751044      0.971414                  8.287856     11.357063
# min      100.000000      1.000000                  0.000692      1.784779
# 25%      620.000000      1.000000                  0.457782     11.018715
# 50%      900.000000      2.000000                  0.698560     13.184035
# 75%     1600.000000      3.000000                  1.087740     17.163502
# max    16521.000000     15.000000               1096.479453   1109.894053
#
#        Aiims_dist_km  NDRLW_dist_km         price
# count   17890.000000   17890.000000  1.789000e+04
# mean       11.238134      11.421994  3.345196e+04
# std        11.167202      11.063323  8.802054e+04
# min         0.634508       0.722023  1.200000e+03
# ...

# %%
price_list=rent_data['price'].values.tolist()

# %% [markdown]
# ## Checking for the outliers

# %%
# 1) Using standard deviation 
outliers=[]
def detect_outliers(data):
    
    threshold=3
    mean = np.mean(data)
    std =np.std(data)
    
    
    for i in data:
        z_score= (i - mean)/std 
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# %%
outlier_pt=detect_outliers(price_list)

# %%
outlier_pt
# Out:
# [450000,
#  415000,
#  425000,
#  421000,
#  440000,
#  400000,
#  460000,
#  300000,
#  400000,
#  325000,
#  350000,
#  425000,
#  325000,
#  325000,
#  350000,
#  400000,
#  400000,
#  510000,
#  300000,
#  350000,
#  400000,
#  300000,
#  350000,
#  500000,
#  400000,
#  350000,
#  350000,
#  330000,
#  300000,
#  330000,
#  300000,
#  450000,
#  350000,
#  450000,
#  320000,
#  350000,
#  350000,
#  400000,
#  500000,
#  350000,
#  350000,
#  500000,
#  350000,
#  425000,
#  325000,
#  350000,
#  500000,
#  300000,
#  350000,
#  330000,
#  325000,
#  450000,
#  450000,
#  350000,
#  450000,
#  300000,
#  300000,
#  350000,
#  300000,
#  800000,
#  986446,
#  2546461,
#  1778448,
#  841246,
#  4011010,
#  3746419,
#  2191911,
#  1010100,
#  1181104,
#  5885646,
#  1854612,
#  4010101,
#  1211818,
#  325000,
#  350000,
#  1450000,
#  375000,
#  500000,
#  300000,
#  500000,
#  350000,
#  325000,
#  350000,
#  425000,
#  350000,
#  300000,
#  500000,
#  430000,
#  400000,
# ...

# %%
len(outlier_pt)
# Out:
# 116

# %% [markdown]
# Here we have got 116 values of rent price as outliers but we will not remove it because it rent price for the house depends on various factors such as type of house, area(sq feet) etc.

# %% [markdown]
# ## Relationship Analysis

# %%
correlation=rent_data.corr()

# %%
correlation
# Out:
#                           size_sq_ft  bedrooms  closest_metro_station_km  \
# size_sq_ft                  1.000000  0.755696                  0.014170
# bedrooms                    0.755696  1.000000                  0.011994
# closest_metro_station_km    0.014170  0.011994                  1.000000
# AP_dist_km                 -0.084951 -0.084629                  0.775016
# Aiims_dist_km              -0.030188  0.040807                  0.799648
# NDRLW_dist_km               0.058507  0.090804                  0.818886
# price                       0.570750  0.379972                  0.003661
#
#                           AP_dist_km  Aiims_dist_km  NDRLW_dist_km     price
# size_sq_ft                 -0.084951      -0.030188       0.058507  0.570750
# bedrooms                   -0.084629       0.040807       0.090804  0.379972
# closest_metro_station_km    0.775016       0.799648       0.818886  0.003661
# AP_dist_km                  1.000000       0.771027       0.698679 -0.009161
# ...

# %%
# Heatmap
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation of different features with price.

# %%
rent_data['price'].corr(rent_data['size_sq_ft'])
# Out:
# 0.5707503034633763

# %%
rent_data['price'].corr(rent_data['bedrooms'])
# Out:
# 0.3799719092495944

# %%
rent_data['price'].corr(rent_data['closest_metro_station_km'])
# Out:
# 0.0036605575925543555

# %%
rent_data['price'].corr(rent_data['AP_dist_km'])
# Out:
# -0.009161173824507526

# %%
rent_data['price'].corr(rent_data['Aiims_dist_km'])
# Out:
# -0.060511087271065925

# %%
rent_data['price'].corr(rent_data['NDRLW_dist_km'])
# Out:
# -0.02434542439819839

# %%
corr=rent_data.corr()[['price']].sort_values(by='price',ascending=False)
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# By seeing above heatmap we can see that size of house(sq.ft),no. of bedrooms are positively correlated with rent price of house
# while Airpot distance,Raillway station distance, AIIMS distance are negatively correlated with rent price of house.

# %% [markdown]
# ## Bar Chart

# %%
rent_data.head()
# Out:
#    size_sq_ft       propertyType  bedrooms         localityName  suburbName  \
# 0         400  Independent Floor         1       Swasthya Vihar  East Delhi
# 1        1050          Apartment         2  mayur vihar phase 1  East Delhi
# 2        2250  Independent Floor         2       Swasthya Vihar  East Delhi
# 3        1350  Independent Floor         2        Krishna Nagar  East Delhi
# 4         450          Apartment         2      New Ashok Nagar  East Delhi
#
#   companyName  closest_metro_station_km  AP_dist_km  Aiims_dist_km  \
# 0       Other                  0.577495   21.741188      11.119239
# 1       Other                  0.417142   21.401856       9.419061
# 2       Other                  0.125136   22.620365      11.829486
# 3       Other                  0.371709   22.681201      11.982708
# 4       Other                  1.087760   22.592810      10.571573
#
#    NDRLW_dist_km  price
# 0       6.227231   9000
# 1       9.217502  20000
# 2       7.159184  28000
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=rent_data['propertyType'],y=rent_data['price'])
plt.title("Property type vs Price",size=15)
plt.xlabel("Type of house (property)",size=12)
plt.ylabel("Rent price ",size=12)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=rent_data['suburbName'],y=rent_data['price'])
plt.title("Suburb Name vs Price",size=15)
plt.xlabel("Urban Regions in Delhi",size=12)
plt.ylabel("Rent price ",size=12)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=rent_data['propertyType'],y=rent_data['size_sq_ft'])
plt.title("Type of house vs size of the house",size=15)
plt.xlabel("Type of house (property)",size=12)
plt.ylabel("Size of house in sq.ft",size=12)
plt.plot()
# Out:
# []

# %%
meanprice = rent_data.groupby('propertyType')['size_sq_ft'].mean()
meanprice
# Out:
# propertyType
# Apartment            1237.212576
# Independent Floor    1137.751738
# Independent House    1063.744420
# Villa                4809.882353
# Name: size_sq_ft, dtype: float64

# %% [markdown]
# ## Scatteplot

# %%
sns.scatterplot(rent_data['size_sq_ft'],rent_data['price'],hue=rent_data['propertyType'])
plt.title("Price vs size of house")
plt.xlabel("Size of house")
plt.ylabel("Rent price")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fg = sns.FacetGrid(rent_data,col="propertyType",col_wrap=2,height=3, aspect=1.2,margin_titles=True, despine=False)
fg.map(plt.scatter,"size_sq_ft","price").add_legend()
plt.show()

# %%
sns.scatterplot(rent_data['bedrooms'],rent_data['price'],hue=rent_data['propertyType'])
plt.title("No. of bedrooms vs Price")
plt.xlabel("No. of bedrooms")
plt.ylabel("Price")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fg = sns.FacetGrid(rent_data,col="propertyType",col_wrap=2,height=3, aspect=1.2,margin_titles=True, despine=False)
fg.map(plt.scatter,"bedrooms","price").add_legend()
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
propertyType_Value=rent_data.propertyType.value_counts().values
propertyType_name=rent_data.propertyType.value_counts().index

# %%
# Pie plot of distribution of PropertyType
plt.pie(propertyType_Value,labels=propertyType_name,autopct='%1.2f%%')
plt.legend(title ="propertyType:",bbox_to_anchor=(1, 1.02), loc='upper left')
plt.title("Distribution of PropertyType",fontweight='bold',loc='center',color='red')
# Out:
# Text(0.5, 1.0, 'Distribution of PropertyType')
